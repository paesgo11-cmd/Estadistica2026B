# %% [markdown]
# <a href="https://colab.research.google.com/github/paesgo11-cmd/Estadistica2026B/blob/main/Problemario_inferencial/Problemario_inferencial_Paolac22150858_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
    })
df
# Out:
#     promedio_de_examenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
#1 Definir variables
x=df["promedio_de_examenes_cortos"]
y=df["promedio_final"]

# %%
#2
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="*",
    color="#DB435C",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="promedio_final" #etiqueta
)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "promedio final",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
#P  A S O 3
# LA PREGUNTA
# 3. ¿Los datos soportan la suposición de linealidad?

# SI, los datos muestran una tendencia aproximadamente lineal.

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
#   p es de prueba de hipótesis
# Ho: P=0 No hay correlación (el cambio en una variable está vinculado al cambio en otra variable)
# H1: P\=0 Sí hay correlación

print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

#     CONCLUSION DE PEARSON

#     COMO EL VALOR DE r ES IGUAL 0.8646, SE RECHAZA H0, por
#     lo cual H1 ES VERDADEA, es decir hay correlación
# Out:
# coeficiente de correlación (r):0.8646
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación 0= r*r
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.7746

# %%
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
#6 Obtenga la recta de regresión ajustada
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                47.487603
# categoria_salario    -2.958678
# dtype: float64

# %%
# R E C T A     P A S O 6
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="*",
    color="#DB435C",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="promedio_final" #etiqueta
)
plt.plot(
    x,y_calculada,
    marker="o",
    color="blue",
    linewidth=2.2,
    linestyle="--",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="Promedio_final"

)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "promedio final",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
#7 Intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_examenes_cortos  0.419219   0.867141

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

#1 residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64

# %%
# 8
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="pink",
    edgecolor="purple", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="promedio_final" #etiqueta
)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "promedio_final",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

plt.axhline(y=0, color="gray", linestyle="--") #linea horizontal

#Parece que siguen el supuesto de linealidad

# %%
#8.-pregunta: ¿Parece que se verifican los supuestos?
#   Los residuos se distribuyen de manera aleatoria alrededor
#   de cero y no tienen un patrón marcado, por lo cual se
#   cumple la linealidad y homocedasticidad.

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"Valor_p: {valor_p:0.4f}")

# Test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

# C O N C L U S I O N
# Como el valor p es mayor a nivel de significacia,
# 0.9018 > 0.05, por lo cual NO SE RECHAZA H0, y se
# acepta; los datos siguen una distribución normal
# Out:
# Valor_p: 0.9018

# %%
#10 Test de Breusch-Pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"valor_p:{valor_p_1:0.4f}")

# Ho: No hay heterocedasticidad (varianza uniforme)
# H1: Hay heterocedasticidad (varianza no uniforme)

# C O N C L U S I O N
# Como el valor p es mayor a el nivel de significancia, 0.2289 > 0.05
# por lo cual NO SE RECHAZA H0, y se acepta; No hay heterocedasticidad,
# por lo tanto, hay homocedasticidad o la varianza es uniforme
# Out:
# valor_p:0.4505

# %%
#11 Tres estudiantes sacaron 70, 75 y 84 de calificación.
#Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?

#f(x)= 24.53 + 0.6432 x
#  x= promedio de examenes cortos
#f(x)= 70
#f(70)= 24.53 + 0.6432(70)
#     =69.55

# x pertenece a [42,97]
# Intrapolación y ectrapolación

# %%
modelo.predict([1,70])
# Out:
# array([69.54941193])

# %%
modelo.predict([1,75])
# Out:
# array([72.76531124])

# %%
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
#12 Tabla/ Test ANOVA
from statsmodels.formula.api import ols

# test de ANOVA (Analysis of Variance)    REVISANDO ( F	/ PR(>F)  )
# H0: beta_1 = 0   (No hay correlación entre las variables)
# H1: beta_1 ≠ 0   (Sí hay correlación entre las variables)

# y ~ x
modelo_lineal=ols("promedio_final~promedio_de_examenes_cortos", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova

# c o n c l u s i o n
#   Como el valor P, es menor al valor del significancia, 0.000032 < 0.05,
#   Se dice que se rechaza H0,por lo cual Sí hay correlacion entre
#   la categoría de promedio de examenes cortos y el promedio final.
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "categoria_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
    })
df
# Out:
#     categoria_salario  ausencias
# 0                  11         18
# 1                  10         17
# 2                   8         29
# 3                   5         36
# 4                   9         11
# 5                   7         28
# 6                   3         35
# 7                  11         14
# 8                   8         20
# 9                   7         32
# 10                  2         39
# 11                  9         16
# 12                  8         31
# 13                  3         40

# %%
#1 Definir variables
x=df["categoria_salario"]
y=df["ausencias"]

# %%
#2
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="d",
    color="black",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Categoria de salario" #etiqueta
)
#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "categoria de salario",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "ausencias",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
# 3 P R E G U N T A : ¿Soporta la suposición de linealidad?
# SI, los datos muestran una tendencia aproximadamente lineal.

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

#    CONCLUSION DE PEARSON

#    COMO EL VALOR DE r ES IGUAL -0.8801
#    SE DEDUCE QUE H1 ES VERDADEA, POR LO CUAL hay correlación
# Out:
# coeficiente de correlación (r):-0.8801
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación 0= r*r
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.7746

# %%
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
#6 Obtenga la recta de regresión ajustada
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                47.487603
# categoria_salario    -2.958678
# dtype: float64

# %%
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="d",
    color="black",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Categoria de salario" #etiqueta
)
plt.plot(
    x, y_calculada,
    color='red',   # color de la línea
    linewidth=0.7,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)
#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "categoria de salario",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "ausencias",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
#7 Intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                            0          1
# const              39.707750  55.267457
# categoria_salario  -3.962455  -1.954900

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

#1 residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64

# %%
#    8
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="H",
    color="orange",
    edgecolor="purple", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Ausencias" #etiqueta
)

#Título
plt.title(
    "Nuevo gráfico de dispersión.",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "categoria de salario",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "ausencias",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

plt.axhline(y=0, color="gray", linestyle="--") #linea horizontal

# %%
#8.-pregunta: ¿Parece que se verifican los supuestos?
#   Los residuos se distribuyen de manera aleatoria alrededor
#   de cero y no tienen un patrón marcado, por lo cual se
#   cumple la linealidad y homocedasticidad.

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"Valor_p: {valor_p:0.4f}")

# Test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

# c o n c l u s i o n
# Como el valor p es mayor a nivel de significacia, valor_p>0.05
# Entonces la hipotesis nula no se rechaza: Los datos siguen una distribución normal
# Out:
# Valor_p: 0.8933

# %%
#10 Test de Breusch-Pagan
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"valor_p:{valor_p_1:0.4f}")

#REVISAR
# Ho: No hay heterocedasticidad (varianza uniforme)
# H1: Hay heterocedasticidad (varianza no uniforme)

# c o n c l u s i o n
# Como el valor P es mayor a el nivel de significancia, entoces la Ho es verdadera
# por lo cual, se deduce que No hay heterocedasticidad,
# por lo tanto, hay homocedasticidad o la varianza es uniforme
# Out:
# valor_p:0.4505

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
df.describe()
# Out:
#        categoria_salario  ausencias
# count          14.000000  14.000000
# mean            7.214286  26.142857
# std             2.939874   9.882830
# min             2.000000  11.000000
# 25%             5.500000  17.250000
# 50%             8.000000  28.500000
# 75%             9.000000  34.250000
# max            11.000000  40.000000

# %%
modelo.params
# Out:
# const                47.487603
# categoria_salario    -2.958678
# dtype: float64

# %%
#f(x)= 47.487603 + (-2.958678) x (constante y complemento)
#  x= categoria_salario [2,11] minimo y maximo

# Intrapolación y ectrapolación
#f(x)= 2,3,4,5,6,7,8,9,10

#f(1)= 47.487603 + (-2.958678) (4)
#                 =4.49188749 (INTERPOLAR)

#(2)= 47.487603 + (-2.958678) (9)
#                 =6.22945142 (INTERPOLAR)

#f(3)= 47.487603 + (-2.958678) (13)
#                 =11.44214319 (EXTRAPOLAR)

# %%
#11 REVISAR   INTER
modelo.predict([1,4])
# Out:
# array([35.65289256])

# %%
#11 REVISAR   INTER
modelo.predict([1,9])
# Out:
# array([20.85950413])

# %%
#11 REVISAR EXTRA
modelo.predict([1,13])
# Out:
# array([9.02479339])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)    REVISANDO ( F / PR(>F)  )
# H0: beta_1 = 0   (No hay correlación entre las variables)
# H1: beta_1 ≠ 0   (Sí hay correlación entre las variables)

#                     Y ~ X
from statsmodels.formula.api import ols
modelo_lineal = ols('ausencias~categoria_salario', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova

# c o n c l u s i o n
#   Como p < 0.05, Se dice que se rechaza H₀,
#   por lo cual Sí hay correlacion entre la categoría
#   de salario y las ausencias
# Out:
#                      df      sum_sq     mean_sq          F    PR(>F)
# categoria_salario   1.0  983.548996  983.548996  41.243954  0.000033
# Residual           12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "gastos_generales":[191,170,272,155,280,173,234,116,153,178],
    "unidades":[40,42,53,35,56,39,48,30,37,40]
    })
df
# Out:
#    gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %%
#1 Definir variables
x=df["gastos_generales"]
y=df["unidades"]

# %%
#2
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="h",
    color="orange",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Gastos generales" #etiqueta
)
#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "gastos generales",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "unidades",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
# 3 P R E G U N T A : ¿Soporta la suposición de linealidad?
# SI, los datos muestran una tendencia aproximadamente lineal.

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

#     CONCLUSION DE PEARSON

#       COMO EL VALOR DE r ES IGUAL 0.9835
#       SE DEDUCE QUE H1 ES VERDADEA, POR LO CUAL hay correlación
# Out:
# coeficiente de correlación (r):0.9835
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación 0= r*r
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9673

# %%
#6 Obtenga la recta de regresión ajustada
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const               13.360132
# gastos_generales     0.149011
# dtype: float64

# %%
#6 Obtenga la recta de regresión ajustada
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="h",
    color="orange",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Gastos generales" #etiqueta
)
plt.plot(
    x, y_calculada,
    color='blue',   # color de la línea
    linewidth=0.7,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)
#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "gastos generales",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "unidades",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
#7 Intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                          0          1
# const             8.920794  17.799471
# gastos_generales  0.126675   0.171347

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

#1 residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0   -1.821187
# 1    3.308039
# 2   -0.891059
# 3   -1.456800
# 4    0.916855
# 5   -0.138993
# 6   -0.228650
# 7   -0.645380
# 8    0.841222
# 9    0.115953
# dtype: float64

# %%
#    8
#Residuales
residuales=modelo.resid
plt.scatter(
    x,residuales,
    marker="H",
    color="orange",
    edgecolor="purple", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Ausencias" #etiqueta
)

#Título
plt.title(
    "Nuevo gráfico de dispersión.",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "gastos generales",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "unidades",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

plt.axhline(y=0, color="gray", linestyle="--") #linea horizontal

# %%
#8.-pregunta: ¿Parece que se verifican los supuestos?
#   Los residuos se distribuyen de manera dispersa alrededor
#   de la línea cero y no tienen un patrón marcado, por lo cual se
#   cumple la linealidad y homocedasticidad.

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"Valor_p: {valor_p:0.4f}")

# Test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

# c o n c l u s i o n
# Como el valor p es mayor a nivel de significacia, valor P> alpha
# 0.3096 > 0.05
# Entonces la hipotesis nula no se rechaza
#Los datos siguen una distribución normal
# Out:
# Valor_p: 0.3096

# %%
#10 Test de Breusch-Pagan
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"valor_p:{valor_p_1:0.4f}")

#REVISAR
# Ho: No hay heterocedasticidad (varianza uniforme)
# H1: Hay heterocedasticidad (varianza no uniforme)

# c o n c l u s i o n
# Como el valor P es mayor a el nivel de significancia,
# 0.6267 > 0.05
# entoces Ho no se rechaza, por lo cual, se deduce que
# No hay heterocedasticidad, hay homocedasticidad o la varianza es uniforme
# Out:
# valor_p:0.6267

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
df.describe()
# Out:
#        gastos_generales   unidades
# count         10.000000  10.000000
# mean         192.200000  42.000000
# std           53.349581   8.082904
# min          116.000000  30.000000
# 25%          158.750000  37.500000
# 50%          175.500000  40.000000
# 75%          223.250000  46.500000
# max          280.000000  56.000000

# %%
modelo.params
# Out:
# const               13.360132
# gastos_generales     0.149011
# dtype: float64

# %%
#f(x)= 13.360132 + 0.149011 x (constante y complemento)
#  x= gastos generales [116,280] minimo y maximo

# Intrapolación y extrapolación
#f(x)= 116 al 279

#f(1)= 13.360132 + 0.149011 (123)
#                         = (INTERPOLAR)

#(2)= 13.360132 + 0.149011 (200)
#                        = (INTERPOLAR)

#f(3)= 13.360132 + 0.149011 (285)
#                         = (EXTRAPOLAR)

# %%
#11 REVISAR   INTER
modelo.predict([1,123])
# Out:
# array([31.68845547])

# %%
#11 REVISAR   INTER
modelo.predict([1,200])
# Out:
# array([43.16228392])

# %%
#11 REVISAR   EXTRAPO
modelo.predict([1,285])
# Out:
# array([55.82819844])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)    REVISANDO ( F	/ PR(>F)  )
# H0: beta_1 = 0   (No hay correlación entre las variables)
# H1: beta_1 ≠ 0   (Sí hay correlación entre las variables)

#                     Y ~ X
from statsmodels.formula.api import ols
modelo_lineal = ols('unidades~gastos_generales', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova

#   c o n c l u s i o n
#   Como p < 0.05, Se dice que se rechaza H₀,
#   por lo cual Sí hay correlacion entre la categoría
#   los gastos generales y las unidades producidas.
# Out:
#                    df      sum_sq     mean_sq           F        PR(>F)
# gastos_generales  1.0  568.774067  568.774067  236.669535  3.167080e-07
# Residual          8.0   19.225933    2.403242         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "construccion_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "venta_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
    })
df
# Out:
#    construccion_casas  venta_linea_blanca
# 0                 2.0                 5.0
# 1                 2.5                 5.5
# 2                 3.2                 6.0
# 3                 3.6                 7.0
# 4                 3.7                 7.2
# 5                 4.0                 7.7
# 6                 4.2                 8.4
# 7                 4.6                 9.0
# 8                 4.8                 9.7
# 9                 5.0                10.0

# %%
# 1. Establesca una variable dependiente ( Y )
# y una variable independiente ( X ).

x = df["construccion_casas"]        # variable independiente (con la que se cuenta)
y = df["venta_linea_blanca"]        # variable de interés (variable dependiente)

# %%
# 2. Realice un diagrama de dispersión para estos datos.
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="H",
    color="orange",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="construccion_casas" #etiqueta
)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "construccion_casas",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "venta_linea_blanca",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
# 3 P R E G U N T A : ¿Soporta la suposición de linealidad?
# SI, los datos muestran una tendencia aproximadamente lineal.

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

#     CONCLUSION DE PEARSON

#       COMO EL VALOR DE r ES IGUAL a 0.9808, El valor es diferente
#       de cero, lo cual me idica que se rechaza H0, por lo cual
#       SE DEDUCE QUE H1 ES VERDADEA, es decir existe correlación
# Out:
# coeficiente de correlación (r):0.9808
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9619

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                 1.016760
# construccion_casas    1.737564
# dtype: float64

# %%
# 6 recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="H",
    color="yellow",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="construccion_casas" #etiqueta
)
plt.plot(
    x,y_calculada,
    marker="o",
   color="blue",
   linewidth=2.2,
   linestyle="--",
   markersize=5,
   markerfacecolor="white",
   markeredgecolor="black",
   label="construccion_casas"

)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "construccion casas",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "venta linea blanca",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                            0         1
# const              -0.074848  2.108368
# construccion_casas  1.455693  2.019435

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

#1 residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0    0.508113
# 1    0.139331
# 2   -0.576964
# 3   -0.271990
# 4   -0.245746
# 5   -0.267015
# 6    0.085472
# 7   -0.009554
# 8    0.342934
# 9    0.295421
# dtype: float64

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. con línea en el centro de 0
#Comente, ¿Parece que se verifican los supuestos?
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="h",
    color="orange",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="construccion_casas" #etiqueta
)

#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "construccion casas",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "venta linea blanca",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="black"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

plt.axhline(y=0, color="gray", linestyle="--") #linea horizontal

# %%
#8.-pregunta: ¿Parece que se verifican los supuestos?
#   Los residuos se distribuyen de manera aleatoria alrededor
#   de cero, solo uno se aproxima mas a ese valor o punto
#   y no tienen un patrón marcado, por lo cual se cumple
#   la linealidad y homocedasticidad.

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"Valor_p: {valor_p:0.4f}")

# Test de Shapiro-Wilk
# H0: Hay normalidad (p>alpha)
# H1: No hay normalidad (p < alpha)
# alpha = 0.05

# c o n c l u s i o n
# Como el valor p es mayor a nivel de significacia,
# 0.8464 > 0.05, Entonces la H0 no se rechaza, por lo cual
# Los datos siguen una distribución normal
# Out:
# Valor_p: 0.8464

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.

# Test de Brausch-Pagan
# Ho: No hay heterocedasticidad, hay homocedasticidad (varianza uniforme)
# (p>alpha)

# H1: Hay heterocedasticidad, No homocedasticidad (varianza no uniforme)
# (p < alpha)

# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"valor_p:{valor_p_1:0.4f}")

# Como el valor p es mayor a el nivel de significancia, entoces la Ho no se rechaza
# es decir, No hay heterocedasticidad, por lo tanto, hay homocedasticidad
# Out:
# valor_p:0.1581

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
df.describe()
# Out:
#        construccion_casas  venta_linea_blanca
# count           10.000000           10.000000
# mean             3.760000            7.550000
# std              0.977753            1.732211
# min              2.000000            5.000000
# 25%              3.300000            6.250000
# 50%              3.850000            7.450000
# 75%              4.500000            8.850000
# max              5.000000           10.000000

# %%
modelo.params
# Out:
# const                 1.016760
# construccion_casas    1.737564
# dtype: float64

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
#Comenta estos resultados.

#f(x)= 1.016760 + 1.737564 x (constante y complemento)
#  x= construccion casas [2,5] minimo y maximo

# Intrapolación y extrapolación
#f(x)= 2,3,4,5
#f(1)= 1.016760 + 1.737564 (1)
#                       = (INTERPOLAR)
#(2)= 1.016760 + 1.737564 (2)
#                       = (INTERPOLAR)
#f(3)= 1.016760 + 1.737564 (1)
#                       = (EXTRAPOLAR)

# %%
modelo.predict([1,2])
#interpolar 1
# Out:
# array([4.49188749])

# %%
modelo.predict([1,3])
#interpolar 2
# Out:
# array([6.22945142])

# %%
modelo.predict([1,6])
#extrapolar 1
# Out:
# array([11.44214319])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)    REVISANDO ( F	/ PR(>F)  )
# H0: beta_1 = 0   (No hay correlación entre las variables)
# H1: beta_1 ≠ 0   (Sí hay correlación entre las variables)

#                     Y ~ X

from statsmodels.formula.api import ols
modelo_lineal=ols("venta_linea_blanca~construccion_casas", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova

# c o n c l u s i o n
#   Como P {PR(>F)} < 0.05, Se dice que se rechaza H₀,
#   por lo cual Sí hay correlacion entre la categoría
#   de salario y las ausencias
# Out:
#                      df     sum_sq    mean_sq           F        PR(>F)
# construccion_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual            8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "interrupciones_trabajador":[5,10,10,15,15,20,20,25],
    "calificacion_trabajador":[58,41,45,27,26,12,16,3]
    })
df
# Out:
#    interrupciones_trabajador  calificacion_trabajador
# 0                          5                       58
# 1                         10                       41
# 2                         10                       45
# 3                         15                       27
# 4                         15                       26
# 5                         20                       12
# 6                         20                       16
# 7                         25                        3

# %%
#1 Definir variables
x=df["interrupciones_trabajador"]
y=df["calificacion_trabajador"]

# %%
#2
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4),  #tamaño (ancho, alto)
    dpi=100         #resolución
)
#Gráfico de dispersión
plt.scatter(
    x,y,
    marker="H",
    color="orange",
    edgecolor="black", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="Interrupciones al trabajador" #etiqueta
)
#Título
plt.title(
    "Gráfico de dispersión",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "interrupciones al trabajador",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "calificacion del trabajador",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

# %%
# 3 P R E G U N T A : ¿Soporta la suposición de linealidad?
# SI, los datos muestran una tendencia aproximadamente lineal.

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

#     CONCLUSION DE PEARSON

#       COMO EL VALOR DE r ES IGUAL -0.9928
#       H1 SE ACEPTA, POR LO CUAL hay correlación
# Out:
# coeficiente de correlación (r):-0.9928
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación 0= r*r
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9858

# %%
modelo.params
# Out:
# const                 1.016760
# construccion_casas    1.737564
# dtype: float64

# %%
#6 Obtenga la recta de regresión ajustada
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                        70.5
# interrupciones_trabajador    -2.8
# dtype: float64

# %%
#7 Intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                    0          1
# const                      65.051384  75.948616
# interrupciones_trabajador  -3.136296  -2.463704

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

#1 residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0    1.5
# 1   -1.5
# 2    2.5
# 3   -1.5
# 4   -2.5
# 5   -2.5
# 6    1.5
# 7    2.5
# dtype: float64

# %%
#    8
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="H",
    color="orange",
    edgecolor="purple", #color de borde
    alpha=0.9, #transparencia
    s=60, #tamaño de punto
    label="interrupciones al trabajador" #etiqueta
)

#Título
plt.title(
    "Nuevo gráfico de dispersión.",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiquetas eje x
plt.xlabel(
    "Interrupciones al trabajador",
    fontsize=10,
)
#Etiqueta eje y
plt.ylabel(
    "calificacion del trabajador",
    fontsize=10
)
#tamaño de los tricks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Márgenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)

plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.7, #ancho de line
    alpha=0.5, #transparencia
    color="blue"
)
    #Leyenda
plt.legend(
        fontsize=10,
        loc="best",
        frameon=False
        #bbox_to_anchor=(0.5.-0.15)
)
        #Guardar imagen
plt.savefig(
            "Dispersión",
            bbox_inches="tight"
        )

plt.axhline(y=0, color="gray", linestyle="--") #linea horizontal

# %%
#8.-pregunta: ¿Parece que se verifican los supuestos?
#   Los residuos se distribuyen de manera aleatoria alrededor
#   de cero y no tienen un patrón marcado, por lo cual se
#   cumple la linealidad y homocedasticidad.

# %%
#9 Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"Valor_p: {valor_p:0.4f}")

# Test de Shapiro-Wilk
# H0: Hay normalidad (p mayor a alpha)
# H1: No hay normalidad (p menor a alpha)
# alpha = 0.05

# c o n c l u s i o n
# Como el valor p es ligeramente mayor a nivel de significacia,
# 0.05848 > 0.05 Entonces la hipotesis nula no se rechaza
# Los datos siguen una distribución normal
# Out:
# Valor_p: 0.0548

# %%
#10 Test de Breusch-Pagan
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales, x_constante)
print(f"valor_p:{valor_p_1:0.4f}")

#REVISAR
# Ho: No hay heterocedasticidad (varianza uniforme) (p mayor a alpha)
# H1: Hay heterocedasticidad (varianza no uniforme) (p menor a alpha)

# c o n c l u s i o n
# Como el valor P es mayor a el nivel de significancia, entoces la Ho
# no se rechaza, por lo cual se deduce que No hay heterocedasticidad,
# por lo tanto, hay homocedasticidad o la varianza es uniforme
# Out:
# valor_p:0.4505

# %%
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
df.describe()
# Out:
#        interrupciones_trabajador  calificacion_trabajador
# count                   8.000000                 8.000000
# mean                   15.000000                28.500000
# std                     6.546537                18.462317
# min                     5.000000                 3.000000
# 25%                    10.000000                15.000000
# 50%                    15.000000                26.500000
# 75%                    20.000000                42.000000
# max                    25.000000                58.000000

# %%
modelo.params
# Out:
# const                        70.5
# interrupciones_trabajador    -2.8
# dtype: float64

# %%
#f(x)= 70.5 + (-2.8) x (constante y complemento)
#  x= categoria_salario [5,25] minimo y maximo

# Intrapolación y extrapolación
#f(x)= 2 al 25 / mayor al 25

#f(1)= 70.5 + (-2.8) (4)
#                 =4.49188749 (INTERPOLAR)

#(2)= 70.5 + (-2.8) (9)
#                 =6.22945142 (INTERPOLAR)

#f(3)= 70.5 + (-2.8) (13)
#                 =11.44214319 (EXTRAPOLAR)

# %%
modelo.predict([1,5])
#interpolar 1
# Out:
# array([56.5])

# %%
modelo.predict([1,15])
#interpolar 1
# Out:
# array([28.5])

# %%
modelo.predict([1,28])
#extrapolar 1
# Out:
# array([-7.9])

# %%
#12 Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)    REVISANDO ( F	/ PR(>F)  )
# H0: beta_1 = 0   (No hay correlación entre las variables)
# H1: beta_1 ≠ 0   (Sí hay correlación entre las variables)

#                     Y ~ X

from statsmodels.formula.api import ols
modelo_lineal=ols("venta_linea_blanca~construccion_casas", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova

# c o n c l u s i o n
#   Como P {PR(>F)} < 0.05, Se dice que se rechaza H₀,
#   por lo cual Sí hay correlacion entre la categoría
#   de salario y las ausencias
# Out:
#                      df     sum_sq    mean_sq           F        PR(>F)
# construccion_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual            8.0   1.028419   0.128552         NaN           NaN
